# %% [markdown]
# <a href="https://colab.research.google.com/github/wilsonmarundaa-netizen/updated-flyRank-intern/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wilsonmarundaa-netizen/updated-flyRank-intern/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# This is classification problem because we need to suggest where a page needs reviewing or not. With that information we can look at what factors make the page need reviewing and improve on that.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# The label here is the trend direction.
#
# The trend direction is the indication of impressions performance in a trend as up or down. Pages with downtrend generally need reviewing to see why they have a downtrend.

# %%
# !wget https://raw.githubusercontent.com/wilsonmarundaa-netizen/updated-flyRank-intern/main/data/raw/content_refresh_anonymized.csv
# Out:
# --2026-08-04 15:22:17--  https://raw.githubusercontent.com/wilsonmarundaa-netizen/updated-flyRank-intern/main/data/raw/content_refresh_anonymized.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6727670 (6.4M) [text/plain]
# Saving to: ‘content_refresh_anonymized.csv’
#
# content_refresh_ano 100%[===================>]   6.42M  26.6MB/s    in 0.2s
#
# 2026-08-04 15:22:18 (26.6 MB/s) - ‘content_refresh_anonymized.csv’ saved [6727670/6727670]

# %%
import pandas as pd

df = pd.read_csv('content_refresh_anonymized.csv')

df.head()
# Out:
#              content_id          client_id  ...  trend_direction  trend_pct
# 0  content_304f48230142  client_f369cb89fc  ...             down      -41.4
# 1  content_a1fb4e703a9e  client_4e07408562  ...             down      -57.7
# 2  content_9aa793d4d895  client_7f2253d7e2  ...             down      -60.9
# 3  content_331d6c4de07b  client_19581e27de  ...           stable      -13.8
# 4  content_d99b7a2d90ca  client_3fdba35f04  ...             down      -34.7
#
# [5 rows x 44 columns]

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# We are going to be using recall of the model which suggests that from all the pages that need reviewing how many did the model actually point out. If a page needs reviewing and is not notes it could cost the company.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row = 90 day performance

# %%
df = pd.read_csv('content_refresh_anonymized.csv')

df.head()
# Out:
#              content_id          client_id  ...  trend_direction  trend_pct
# 0  content_304f48230142  client_f369cb89fc  ...             down      -41.4
# 1  content_a1fb4e703a9e  client_4e07408562  ...             down      -57.7
# 2  content_9aa793d4d895  client_7f2253d7e2  ...             down      -60.9
# 3  content_331d6c4de07b  client_19581e27de  ...           stable      -13.8
# 4  content_d99b7a2d90ca  client_3fdba35f04  ...             down      -34.7
#
# [5 rows x 44 columns]

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# The reason ML beats a fixed rule is because it helps suggest solutions in future cases. A rule is based the trend direction which is basically an outcome of the overall impression trend over time. There other factors than impressions that may lead to the downtrend and this is where ML comes to learn the hidden patterns and help suggest the future outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
